# %%
from bs4 import BeautifulSoup
import requests

# %%
url = "https://en.wikipedia.org/wiki/List_of_unicorn_startup_companies"
page = requests.get(url)
soup=BeautifulSoup(page.text, 'html')

# %%
print(soup)

# %%
soup.find('table')
# Out:
# <table class="wikitable">
# <caption>Historical progress of unicorns
# </caption>
# <tbody><tr>
# <th># Unicorns
# </th>
# <th>Total valuation<br/>(US$ billions)
# </th>
# <th>Date
# </th>
# <th>Reported by
# </th></tr>
# <tr>
# <td>39
# </td>
# <td>
# </td>
# <td>Late October/Early November 2013
# </td>
# <td><i>TechCrunch</i><sup class="reference" id="cite_ref-8"><a href="#cite_note-8">[8]</a></sup>
# </td></tr>
# <tr>
# <td>82
# </td>
# <td>
# </td>
# <td>Late January 2015
# </td>
# <td><i><a href="/wiki/Forbes" title="Forbes">Forbes</a></i>, CB Insights<sup class="reference" id="cite_ref-9"><a href="#cite_note-9">[9]</a></sup>
# </td></tr>
# <tr>
# <td>229
# </td>
# <td>1,300
# </td>
# <td>January 2016
# </td>
# <td><i><a href="/wiki/VentureBeat" title="VentureBeat">VentureBeat</a></i><sup class="reference" id="cite_ref-10"><a href="#cite_note-10">[10]</a></sup>
# </td></tr>
# <tr>
# <td>208
# </td>
# <td>761
# </td>
# <td>December 2016
# </td>
# ...

# %%
soup.find_all('table')[2]
# Out:
# <table class="wikitable sortable sticky-header">
# <tbody><tr>
# <th>Company
# </th>
# <th>Valuation<br/>(US$ billions)
# </th>
# <th>Valuation date
# </th>
# <th>Industry
# </th>
# <th>Country/<br/>countries
# </th>
# <th>Founder(s)
# </th></tr>
# <tr>
# <td><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# </td>
# <td>175
# </td>
# <td>December 2023<span style="display:none"> (<span class="bday dtstart published updated itvstart">2023-12</span>)</span> <sup class="reference" id="cite_ref-20"><a href="#cite_note-20">[20]</a></sup>
# </td>
# <td><a href="/wiki/Aerospace" title="Aerospace">Aerospace</a>
# </td>
# <td>United States
# </td>
# <td><a href="/wiki/Elon_Musk" title="Elon Musk">Elon Musk</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/OpenAI" title="OpenAI">OpenAI</a>
# </td>
# <td>80-90
# </td>
# ...

# %%
table = soup.find_all('table')[2]

# %%
table.find_all('th')
# Out:
# [<th>Company
#  </th>,
#  <th>Valuation<br/>(US$ billions)
#  </th>,
#  <th>Valuation date
#  </th>,
#  <th>Industry
#  </th>,
#  <th>Country/<br/>countries
#  </th>,
#  <th>Founder(s)
#  </th>]

# %%
titles=table.find_all('th')

# %%
titles
# Out:
# [<th>Company
#  </th>,
#  <th>Valuation<br/>(US$ billions)
#  </th>,
#  <th>Valuation date
#  </th>,
#  <th>Industry
#  </th>,
#  <th>Country/<br/>countries
#  </th>,
#  <th>Founder(s)
#  </th>]

# %%
table_titles=[title.text.strip() for title in titles]
print(table_titles)
# Out:
# ['Company', 'Valuation(US$ billions)', 'Valuation date', 'Industry', 'Country/countries', 'Founder(s)']

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns=table_titles)
df
# Out:
# Empty DataFrame
# Columns: [Company, Valuation(US$ billions), Valuation date, Industry, Country/countries, Founder(s)]
# Index: []

# %%
column_data=table.find_all('tr')

# %%
for row in column_data[1:]:
    row_data=row.find_all('td')
    row_index_data=[data.text.strip() for data in row_data]
    
    length=len(df)
    df.loc[length]=row_index_data

# %%
df
# Out:
#             Company Valuation(US$ billions)                Valuation date  \
# 0            SpaceX                     175  December 2023 (2023-12) [20]
# 1            OpenAI                   80-90  September 2023 (2023-09)[21]
# 2           Binance                   80-90  September 2021 (2021-09)[13]
# 3             Shein                      66       May 2023 (2023-05) [13]
# 4            Stripe                      50     March 2023 (2023-03) [13]
# ..              ...                     ...                           ...
# 671   Neo Financial                       1                 May 2022[594]
# 672  Physics Wallah                     1.1                June 2022[595]
# 673          Stytch                       1            November 2021[596]
# 674          Papara                       1                July 2023[597]
# 675   Younited [fr]                     1.1            December 2022[598]
#
#                     Industry          Country/countries  \
# ...

# %%
df.to_csv(r'/home/sal/Downloads/companies.csv', index=False)
